# %%
import matplotlib
import matplotlib.pyplot as plt
import os
from PIL import Image  # PIL is the Python Imaging Library, used for opening image files

# Load the image file (replace 'path/to/your/image.jpg' with the actual path)
static_image_path1 = r"C:/Users/email/Downloads/Lego Classification DataSet/64/99781/998.jpg"
static_image1 = Image.open(static_image_path1)

# Display the image
plt.imshow(static_image1)
plt.axis('off')  # Optional: Hide the axis for a cleaner look
plt.show()

static_image_path2 = r"C:\Users\email\Downloads\Lego Classification DataSet\64\30136\43.jpg"
static_image2 = Image.open(static_image_path2)

# Display the image
plt.imshow(static_image2)
plt.axis('off')  # Optional: Hide the axis for a cleaner look
plt.show()
